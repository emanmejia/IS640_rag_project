# %% [markdown]
# 1000 characters per file x 5docs.
# Which documents should we run - Recipes.  Get minimum requirements.
# Each file requires to have 1000 characters.
# Stick with Recipes.
# Copy repository to local file.
# If we create an agent we will get extra points.
# **ENSURE IT WORKS OFFLINE**

# %% [markdown]
# Give prompts that are very detailed, try trusting your LLM with different prompts.
# It can't be perfect, but try to ensure it is detailed enough to get the right output.
# He struggled a lot on calculations - so try not to ask it to calculate things.
# Lets have it locally versus on Github
