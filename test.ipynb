# %%
print("Hello")
# Out:
# Hello

# %%
from random import randint

# %%
randint(1, 10)
# Out:
# 5

# %%
import requests
r = requests.post(
    "http://127.0.0.1:11434/api/generate",
    json={"model": "mistral:7b", "prompt": "Answer in one sentence: What is 2+5?", "stream": False},
    timeout=60
)
print(r.status_code, r.text)
# Out:
# 200 {"model":"mistral:7b","created_at":"2025-11-22T03:17:31.124768277Z","response":" The sum of 2 and 5 is 7.","done":true,"done_reason":"stop","context":[3,29473,27075,1065,1392,13039,29515,2592,1117,29473,29518,29574,29550,29572,4,29473,1183,3416,1070,29473,29518,1072,29473,29550,1117,29473,29555,29491],"total_duration":20867632057,"load_duration":12597192831,"prompt_eval_count":16,"prompt_eval_duration":3714942264,"eval_count":13,"eval_duration":4538094010}
