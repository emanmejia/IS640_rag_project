# %%
print("Hello")
# Out:
# Hello

# %%
from random import randint

# %%
randint(1, 10)
# Out:
# 2

# %%
import requests
r = requests.post(
    "http://127.0.0.1:11434/api/generate",
    json={"model": "mistral:7b", "prompt": "Answer in one sentence: What is 2+2?", "stream": False},
    timeout=60
)
print(r.status_code, r.text)
# Out:
# 200 {"model":"mistral:7b","created_at":"2025-11-12T06:36:17.328437049Z","response":" The sum of 2 and 2 is 4.","done":true,"done_reason":"stop","context":[3,29473,27075,1065,1392,13039,29515,2592,1117,29473,29518,29574,29518,29572,4,29473,1183,3416,1070,29473,29518,1072,29473,29518,1117,29473,29549,29491],"total_duration":15315571417,"load_duration":8822183418,"prompt_eval_count":16,"prompt_eval_duration":3328166339,"eval_count":13,"eval_duration":3134634659}
